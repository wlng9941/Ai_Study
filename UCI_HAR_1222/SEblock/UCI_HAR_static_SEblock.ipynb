# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras
from sklearn.metrics import precision_score, recall_score, f1_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, Activation, UpSampling1D
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling1D
from keras import  backend as K

# %%
 from typing import Any, Dict, List, Tuple
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)

# %%
from sklearn.preprocessing import StandardScaler

def scale_data(trainX, testX):
 # remove overlap
 cut = int(trainX.shape[1] / 2)
 longX = trainX[:, -cut:, :]
 # flatten windows
 longX = longX.reshape((longX.shape[0] * longX.shape[1], longX.shape[2]))
 # flatten train and test
 flatTrainX = trainX.reshape((trainX.shape[0] * trainX.shape[1], trainX.shape[2]))
 flatTestX = testX.reshape((testX.shape[0] * testX.shape[1], testX.shape[2]))

 s = StandardScaler()
 # fit on training data
 s.fit(longX)
 # apply to training and test data
 longX = s.transform(longX)
 flatTrainX = s.transform(flatTrainX)
 flatTestX = s.transform(flatTestX)
 # reshape
 flatTrainX = flatTrainX.reshape((trainX.shape))
 flatTestX = flatTestX.reshape((testX.shape))
 return flatTrainX, flatTestX

# %%
trainX, testX = scale_data(trainX, testX)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
print("0: Walking:" ,np.where(trainy == 0)[0].size)
print("1: WU:" ,np.where(trainy == 1)[0].size)
print("2: WD:" ,np.where(trainy == 2)[0].size)
print("3: Sitting:" ,np.where(trainy == 3)[0].size)
print("4: Standing:" ,np.where(trainy == 4)[0].size)
print("5: Laying:" ,np.where(trainy == 5)[0].size)
# Out:
# 0: Walking: 1226
# 1: WU: 1073
# 2: WD: 986
# 3: Sitting: 1286
# 4: Standing: 1374
# 5: Laying: 1407

# %%
X_train_all = trainX   # at this stage, the data includes both dynamic and static HAR data
y_train_all = trainy

X_test_all = testX
y_test_all = testy

# %%
import random

static_1 = np.where(trainy == 3)[0]
static_2 = np.where(trainy == 4)[0]
static_3 = np.where(trainy == 5)[0]
static = np.concatenate([static_1, static_2, static_3])
static_list = static.tolist()

# Shuffle dynamic data index
r = random.random()
random.shuffle(static_list, lambda: r)

static = np.array(static)

trainX = X_train_all[static]
trainy = y_train_all[static]
# Out:
# <ipython-input-11-9dd469a3f9cb>:11: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(static_list, lambda: r)

# %%
static_1 = np.where(testy == 3)[0]
static_2 = np.where(testy == 4)[0]
static_3 = np.where(testy == 5)[0]
static = np.concatenate([static_1, static_2, static_3])
static_list = static.tolist()

r = random.random()
random.shuffle(static_list, lambda: r)

static = np.array(static_list)

testX = X_test_all[static]
testy = y_test_all[static]
# Out:
# <ipython-input-12-f391b7cb3b7b>:8: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(static_list, lambda: r)

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  3 491]
#  [  4 532]
#  [  5 537]]

# %%
trainy = trainy - 3
testy = testy - 3
trainy_one_hot = to_categorical(trainy)
testy_one_hot = to_categorical(testy)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (4067, 128, 9)
# Y train shape:  (4067, 1)
# Y train One hot shape:  (4067, 3)
# X test shape:  (1560, 128, 9)
# Y test shape:  (1560, 1)
# Y test One hot shape:  (1560, 3)

# %%
def class_breakdown(data):
    # convert the numpy array into a dataframe
    df = pd.DataFrame(data)
    # group data by the class value and calculate the number of rows
    counts = df.groupby(0).size()
    # retrieve raw rows
    counts = counts.values
    # summarize
    for i in range(len(counts)):
        percent = counts[i] / len(df) * 100
        print('Class=%d, total=%d, percentage=%.3f' % (i+1, counts[i], percent))

# %%
class_breakdown(y_train)
# Out:
# Class=1, total=877, percentage=30.815
# Class=2, total=972, percentage=34.153
# Class=3, total=997, percentage=35.032

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.3,random_state=100)

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy_one_hot.shape[1]

# %% [markdown]
# # Training

# %%
def conv_block(in_x, nb_filter, kernel_size):

    x = Conv1D(nb_filter, kernel_size, padding='same')(in_x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def convolutional_block(in_x, nb_filters, stride):

    F1, F2, F3 = nb_filters

    x = in_x

    x = Conv1D(F1, 3, strides=stride,  padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F2, 3, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F3, 1, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)

    #----------------------------------------------

    x1 = Conv1D(F3, 1, strides=stride, padding='same', kernel_initializer="he_normal")(in_x)
    x1 = BatchNormalization()(x1)

    x = add([x, x1])
    x = Activation('relu')(x)

    return x

# %%
# SE block은 채널 마다 가중치를 주어 합성곱을 수행
# 채널 간의 의존성을 고려하여 효과적인 특성 강조를 수행하는 방법 동입
# squeeze : Global average pooling을 사용하여 채널별로 평균값을 계산하여 각 채널의 중요도를 파악한다.
# excitation : Fully connected layer , 활성화함수를 통해서 각 채널의 가중치 조정, 채널 같의 관계 모델링
def se_block(in_x, nb_filter):
        # GAP층 사용하여 (특징 맵에서 각 채널의 평균으로 축소)
        squeeze = GlobalAveragePooling1D()(in_x)
        # flatten 층 없이 cnn의 특성 맵을 직접 dense층에 입력 -> 공간 정보를 유지한 채로 전달한다.
        excitation = Dense(units=nb_filter // 2)(squeeze)
        # 필터의 개수는 입력 -> 출력에서 얼마다 다운샘플링 하는지 비율을 뜻한다.
        excitation = Activation('relu')(excitation)
        excitation = Dense(units=nb_filter)(excitation)
        excitation = Activation('sigmoid')(excitation)
        excitation = Reshape((1,nb_filter))(excitation)
        # 처음 필터의 개수 ( 채널 수)로 reshape하여 각 채널의 중요도(가중치)를 채널에 곱하는 연산을 수행
        scale = multiply([in_x,excitation])
        out = add([in_x, scale])

        return out

# %%
def SENET():

    inputs = Input(shape=(n_timesteps,n_features))
    # (none, 128, 9)
    x = Conv1D(16, 32, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 16)
    x = MaxPooling1D(4)(x)

    x = Conv1D(32, 16, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 32)
    x = MaxPooling1D(4)(x)

    x = Flatten()(x)
    x = Dense(128,  activation='relu')(x)
    x = Dense(n_outputs,  activation='softmax')(x)

    model = keras.Model(inputs, x)

    return model

# %%
model = SENET()
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_10 (InputLayer)       [(None, 128, 9)]             0         []
#
#  conv1d_18 (Conv1D)          (None, 128, 16)              4624      ['input_10[0][0]']
#
#  batch_normalization_18 (Ba  (None, 128, 16)              64        ['conv1d_18[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 128, 16)              0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  global_average_pooling1d_1  (None, 16)                   0         ['activation_54[0][0]']
#  8 (GlobalAveragePooling1D)
#
#  dense_54 (Dense)            (None, 8)                    136       ['global_average_pooling1d_18[
#                                                                     0][0]']
#
#  activation_55 (Activation)  (None, 8)                    0         ['dense_54[0][0]']
#
#  dense_55 (Dense)            (None, 16)                   144       ['activation_55[0][0]']
#
#  activation_56 (Activation)  (None, 16)                   0         ['dense_55[0][0]']
#
#  reshape_18 (Reshape)        (None, 1, 16)                0         ['activation_56[0][0]']
#
#  multiply_18 (Multiply)      (None, 128, 16)              0         ['activation_54[0][0]',
#                                                                      'reshape_18[0][0]']
#
#  add_18 (Add)                (None, 128, 16)              0         ['activation_54[0][0]',
#                                                                      'multiply_18[0][0]']
#
#  max_pooling1d_18 (MaxPooli  (None, 32, 16)               0         ['add_18[0][0]']
#  ng1D)
#
#  conv1d_19 (Conv1D)          (None, 32, 32)               8224      ['max_pooling1d_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 32, 32)               128       ['conv1d_19[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 32, 32)               0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  global_average_pooling1d_1  (None, 32)                   0         ['activation_57[0][0]']
#  9 (GlobalAveragePooling1D)
#
#  dense_56 (Dense)            (None, 16)                   528       ['global_average_pooling1d_19[
#                                                                     0][0]']
#
#  activation_58 (Activation)  (None, 16)                   0         ['dense_56[0][0]']
#
#  dense_57 (Dense)            (None, 32)                   544       ['activation_58[0][0]']
#
#  activation_59 (Activation)  (None, 32)                   0         ['dense_57[0][0]']
#
#  reshape_19 (Reshape)        (None, 1, 32)                0         ['activation_59[0][0]']
#
#  multiply_19 (Multiply)      (None, 32, 32)               0         ['activation_57[0][0]',
#                                                                      'reshape_19[0][0]']
#
#  add_19 (Add)                (None, 32, 32)               0         ['activation_57[0][0]',
#                                                                      'multiply_19[0][0]']
#
#  max_pooling1d_19 (MaxPooli  (None, 8, 32)                0         ['add_19[0][0]']
#  ng1D)
#
#  flatten_9 (Flatten)         (None, 256)                  0         ['max_pooling1d_19[0][0]']
#
#  dense_58 (Dense)            (None, 128)                  32896     ['flatten_9[0][0]']
#
#  dense_59 (Dense)            (None, 3)                    387       ['dense_58[0][0]']
#
# ==================================================================================================
# Total params: 47675 (186.23 KB)
# Trainable params: 47579 (185.86 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
# validation_split = 0.1
batch_size = 32

train_epochs = 100
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(trainX, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_one_hot), shuffle=True)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 7s 26ms/step - loss: 0.2787 - accuracy: 0.8847 - val_loss: 0.2095 - val_accuracy: 0.8993
# Epoch 2/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2199 - accuracy: 0.9100 - val_loss: 0.1866 - val_accuracy: 0.9140
# Epoch 3/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.2088 - accuracy: 0.9142 - val_loss: 0.1925 - val_accuracy: 0.9173
# Epoch 4/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.2165 - accuracy: 0.9105 - val_loss: 0.1859 - val_accuracy: 0.9156
# Epoch 5/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.2235 - accuracy: 0.9041 - val_loss: 0.1860 - val_accuracy: 0.9017
# Epoch 6/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1906 - accuracy: 0.9149 - val_loss: 0.1604 - val_accuracy: 0.9304
# Epoch 7/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1834 - accuracy: 0.9208 - val_loss: 0.1543 - val_accuracy: 0.9287
# Epoch 8/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1792 - accuracy: 0.9253 - val_loss: 0.1569 - val_accuracy: 0.9361
# Epoch 9/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1616 - accuracy: 0.9331 - val_loss: 0.1589 - val_accuracy: 0.9255
# Epoch 10/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1869 - accuracy: 0.9218 - val_loss: 0.1669 - val_accuracy: 0.9296
# Epoch 11/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.2127 - accuracy: 0.9159 - val_loss: 0.1639 - val_accuracy: 0.9345
# Epoch 12/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1653 - accuracy: 0.9314 - val_loss: 0.1437 - val_accuracy: 0.9386
# Epoch 13/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1593 - accuracy: 0.9341 - val_loss: 0.1402 - val_accuracy: 0.9402
# Epoch 14/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.1700 - accuracy: 0.9287 - val_loss: 0.1472 - val_accuracy: 0.9427
# Epoch 15/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1494 - accuracy: 0.9385 - val_loss: 0.1245 - val_accuracy: 0.9459
# Epoch 16/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1358 - accuracy: 0.9410 - val_loss: 0.1245 - val_accuracy: 0.9574
# Epoch 17/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1376 - accuracy: 0.9447 - val_loss: 0.1334 - val_accuracy: 0.9435
# Epoch 18/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1553 - accuracy: 0.9366 - val_loss: 0.1219 - val_accuracy: 0.9517
# Epoch 19/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1305 - accuracy: 0.9479 - val_loss: 0.1190 - val_accuracy: 0.9533
# Epoch 20/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1293 - accuracy: 0.9506 - val_loss: 0.1028 - val_accuracy: 0.9623
# Epoch 21/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1241 - accuracy: 0.9491 - val_loss: 0.1065 - val_accuracy: 0.9590
# Epoch 22/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.1254 - accuracy: 0.9471 - val_loss: 0.1311 - val_accuracy: 0.9353
# Epoch 23/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1069 - accuracy: 0.9557 - val_loss: 0.0945 - val_accuracy: 0.9730
# Epoch 24/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1098 - accuracy: 0.9570 - val_loss: 0.0947 - val_accuracy: 0.9582
# Epoch 25/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1252 - accuracy: 0.9496 - val_loss: 0.0901 - val_accuracy: 0.9656
# Epoch 26/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1161 - accuracy: 0.9545 - val_loss: 0.0896 - val_accuracy: 0.9664
# Epoch 27/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0928 - accuracy: 0.9673 - val_loss: 0.1148 - val_accuracy: 0.9533
# Epoch 28/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0979 - accuracy: 0.9609 - val_loss: 0.0835 - val_accuracy: 0.9664
# Epoch 29/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1065 - accuracy: 0.9607 - val_loss: 0.0721 - val_accuracy: 0.9730
# Epoch 30/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1013 - accuracy: 0.9604 - val_loss: 0.0769 - val_accuracy: 0.9705
# Epoch 31/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0904 - accuracy: 0.9621 - val_loss: 0.1135 - val_accuracy: 0.9566
# Epoch 32/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0977 - accuracy: 0.9599 - val_loss: 0.0744 - val_accuracy: 0.9738
# Epoch 33/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1156 - accuracy: 0.9548 - val_loss: 0.0804 - val_accuracy: 0.9722
# Epoch 34/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0957 - accuracy: 0.9631 - val_loss: 0.0654 - val_accuracy: 0.9762
# Epoch 35/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0808 - accuracy: 0.9668 - val_loss: 0.0598 - val_accuracy: 0.9795
# Epoch 36/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0725 - accuracy: 0.9705 - val_loss: 0.0753 - val_accuracy: 0.9664
# Epoch 37/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0733 - accuracy: 0.9693 - val_loss: 0.0563 - val_accuracy: 0.9771
# Epoch 38/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0630 - accuracy: 0.9766 - val_loss: 0.0502 - val_accuracy: 0.9803
# Epoch 39/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0683 - accuracy: 0.9725 - val_loss: 0.0621 - val_accuracy: 0.9754
# Epoch 40/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0652 - accuracy: 0.9766 - val_loss: 0.0741 - val_accuracy: 0.9722
# Epoch 41/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.1515 - accuracy: 0.9371 - val_loss: 0.0951 - val_accuracy: 0.9664
# Epoch 42/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0837 - accuracy: 0.9648 - val_loss: 0.0589 - val_accuracy: 0.9762
# Epoch 43/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0600 - accuracy: 0.9737 - val_loss: 0.0446 - val_accuracy: 0.9861
# Epoch 44/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0648 - accuracy: 0.9752 - val_loss: 0.0595 - val_accuracy: 0.9812
# Epoch 45/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0815 - accuracy: 0.9717 - val_loss: 0.0455 - val_accuracy: 0.9795
# Epoch 46/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0449 - accuracy: 0.9840 - val_loss: 0.0575 - val_accuracy: 0.9762
# Epoch 47/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0509 - accuracy: 0.9779 - val_loss: 0.0660 - val_accuracy: 0.9713
# Epoch 48/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0952 - accuracy: 0.9671 - val_loss: 0.0531 - val_accuracy: 0.9771
# Epoch 49/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0551 - accuracy: 0.9789 - val_loss: 0.0394 - val_accuracy: 0.9869
# Epoch 50/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0465 - accuracy: 0.9825 - val_loss: 0.0387 - val_accuracy: 0.9869
# Epoch 51/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0727 - accuracy: 0.9725 - val_loss: 0.0444 - val_accuracy: 0.9869
# Epoch 52/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0502 - accuracy: 0.9811 - val_loss: 0.0390 - val_accuracy: 0.9869
# Epoch 53/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0467 - accuracy: 0.9838 - val_loss: 0.0319 - val_accuracy: 0.9877
# Epoch 54/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0368 - accuracy: 0.9870 - val_loss: 0.0320 - val_accuracy: 0.9853
# Epoch 55/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0896 - accuracy: 0.9661 - val_loss: 0.0468 - val_accuracy: 0.9828
# Epoch 56/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0439 - accuracy: 0.9833 - val_loss: 0.0342 - val_accuracy: 0.9877
# Epoch 57/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0397 - accuracy: 0.9852 - val_loss: 0.0315 - val_accuracy: 0.9894
# Epoch 58/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0325 - accuracy: 0.9880 - val_loss: 0.0276 - val_accuracy: 0.9910
# Epoch 59/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0328 - accuracy: 0.9899 - val_loss: 0.0144 - val_accuracy: 0.9975
# Epoch 60/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0333 - accuracy: 0.9882 - val_loss: 0.0400 - val_accuracy: 0.9795
# Epoch 61/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0282 - accuracy: 0.9894 - val_loss: 0.0264 - val_accuracy: 0.9877
# Epoch 62/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0326 - accuracy: 0.9892 - val_loss: 0.1000 - val_accuracy: 0.9599
# Epoch 63/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0375 - accuracy: 0.9843 - val_loss: 0.0138 - val_accuracy: 0.9975
# Epoch 64/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0196 - accuracy: 0.9946 - val_loss: 0.0135 - val_accuracy: 0.9959
# Epoch 65/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1503 - accuracy: 0.9471 - val_loss: 0.0877 - val_accuracy: 0.9664
# Epoch 66/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0858 - accuracy: 0.9683 - val_loss: 0.0585 - val_accuracy: 0.9771
# Epoch 67/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0762 - accuracy: 0.9661 - val_loss: 0.0447 - val_accuracy: 0.9828
# Epoch 68/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0602 - accuracy: 0.9744 - val_loss: 0.0403 - val_accuracy: 0.9828
# Epoch 69/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0422 - accuracy: 0.9825 - val_loss: 0.0305 - val_accuracy: 0.9894
# Epoch 70/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0373 - accuracy: 0.9850 - val_loss: 0.0264 - val_accuracy: 0.9918
# Epoch 71/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0338 - accuracy: 0.9855 - val_loss: 0.0315 - val_accuracy: 0.9885
# Epoch 72/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0396 - accuracy: 0.9845 - val_loss: 0.0469 - val_accuracy: 0.9828
# Epoch 73/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.0217 - val_accuracy: 0.9951
# Epoch 74/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0320 - accuracy: 0.9877 - val_loss: 0.0156 - val_accuracy: 0.9959
# Epoch 75/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0345 - accuracy: 0.9877 - val_loss: 0.0218 - val_accuracy: 0.9951
# Epoch 76/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0315 - accuracy: 0.9894 - val_loss: 0.0133 - val_accuracy: 0.9984
# Epoch 77/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0336 - accuracy: 0.9880 - val_loss: 0.0128 - val_accuracy: 0.9959
# Epoch 78/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0274 - accuracy: 0.9892 - val_loss: 0.0138 - val_accuracy: 0.9967
# Epoch 79/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0266 - accuracy: 0.9909 - val_loss: 0.0114 - val_accuracy: 0.9959
# Epoch 80/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0211 - accuracy: 0.9899 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 81/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 82/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0149 - accuracy: 0.9941 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 83/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 84/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0148 - accuracy: 0.9953 - val_loss: 0.0226 - val_accuracy: 0.9918
# Epoch 85/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0429 - accuracy: 0.9848 - val_loss: 0.0241 - val_accuracy: 0.9910
# Epoch 86/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0156 - accuracy: 0.9946 - val_loss: 0.0109 - val_accuracy: 0.9967
# Epoch 87/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0178 - accuracy: 0.9934 - val_loss: 0.0092 - val_accuracy: 0.9984
# Epoch 88/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0455 - accuracy: 0.9848 - val_loss: 0.0269 - val_accuracy: 0.9869
# Epoch 89/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0437 - accuracy: 0.9870 - val_loss: 0.0216 - val_accuracy: 0.9943
# Epoch 90/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0158 - accuracy: 0.9931 - val_loss: 0.0085 - val_accuracy: 0.9975
# Epoch 91/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0160 - accuracy: 0.9958 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 92/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0322 - accuracy: 0.9882 - val_loss: 0.0441 - val_accuracy: 0.9803
# Epoch 93/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 94/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0107 - accuracy: 0.9978 - val_loss: 0.0029 - val_accuracy: 0.9992
# Epoch 95/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0071 - accuracy: 0.9978 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 96/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0131 - accuracy: 0.9975 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 97/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0659 - accuracy: 0.9754 - val_loss: 0.0329 - val_accuracy: 0.9861
# Epoch 98/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0184 - accuracy: 0.9924 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 99/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 100/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0023 - val_accuracy: 1.0000

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(testX)
predy=np.argmax(predy, axis=-1)
LABELS = ['SITTING','STANDIND','LAYING']
cm=confusion_matrix(testy,predy)
print(cm)
print(accuracy_score(testy,predy))
print(f1_score(testy,predy, average='weighted'))
print(classification_report(testy,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 49/49 [==============================] - 0s 4ms/step
# [[419  71   1]
#  [ 20 512   0]
#  [  0   0 537]]
# 0.941025641025641
# 0.9407112743748777
#               precision    recall  f1-score   support
#
#            0       0.95      0.85      0.90       491
#            1       0.88      0.96      0.92       532
#            2       1.00      1.00      1.00       537
#
#     accuracy                           0.94      1560
#    macro avg       0.94      0.94      0.94      1560
# weighted avg       0.94      0.94      0.94      1560
# <Axes: >

# %%
def en_loss(y_true, y_pred):

    epsilon = 1.e-7
    gamma = float(0.3)

    y_true = tf.cast(y_true, tf.float32)
    # 텐서의 데이터 타입 변경
    y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
    # 텐서의 값을 지정된 범위로 제한. : y_pred의 값을 epsilon과 1. - epsilon 사이
    pos_pred = tf.pow(-tf.math.log(y_pred),gamma)
    nag_pred = tf.pow(-tf.math.log(1-y_pred),gamma)
    y_t = tf.multiply(y_true, pos_pred) + tf.multiply(1-y_true, nag_pred)
    en_loss = tf.reduce_mean(y_t)
    return en_loss

# %%
model = SENET()
model.summary()
model.compile(optimizer = 'adam', loss=en_loss, metrics = ["accuracy"])
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_11 (InputLayer)       [(None, 128, 9)]             0         []
#
#  conv1d_20 (Conv1D)          (None, 128, 16)              4624      ['input_11[0][0]']
#
#  batch_normalization_20 (Ba  (None, 128, 16)              64        ['conv1d_20[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 128, 16)              0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  global_average_pooling1d_2  (None, 16)                   0         ['activation_60[0][0]']
#  0 (GlobalAveragePooling1D)
#
#  dense_60 (Dense)            (None, 8)                    136       ['global_average_pooling1d_20[
#                                                                     0][0]']
#
#  activation_61 (Activation)  (None, 8)                    0         ['dense_60[0][0]']
#
#  dense_61 (Dense)            (None, 16)                   144       ['activation_61[0][0]']
#
#  activation_62 (Activation)  (None, 16)                   0         ['dense_61[0][0]']
#
#  reshape_20 (Reshape)        (None, 1, 16)                0         ['activation_62[0][0]']
#
#  multiply_20 (Multiply)      (None, 128, 16)              0         ['activation_60[0][0]',
#                                                                      'reshape_20[0][0]']
#
#  add_20 (Add)                (None, 128, 16)              0         ['activation_60[0][0]',
#                                                                      'multiply_20[0][0]']
#
#  max_pooling1d_20 (MaxPooli  (None, 32, 16)               0         ['add_20[0][0]']
#  ng1D)
#
#  conv1d_21 (Conv1D)          (None, 32, 32)               8224      ['max_pooling1d_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 32, 32)               128       ['conv1d_21[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 32, 32)               0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  global_average_pooling1d_2  (None, 32)                   0         ['activation_63[0][0]']
#  1 (GlobalAveragePooling1D)
#
#  dense_62 (Dense)            (None, 16)                   528       ['global_average_pooling1d_21[
#                                                                     0][0]']
#
#  activation_64 (Activation)  (None, 16)                   0         ['dense_62[0][0]']
#
#  dense_63 (Dense)            (None, 32)                   544       ['activation_64[0][0]']
#
#  activation_65 (Activation)  (None, 32)                   0         ['dense_63[0][0]']
#
#  reshape_21 (Reshape)        (None, 1, 32)                0         ['activation_65[0][0]']
#
#  multiply_21 (Multiply)      (None, 32, 32)               0         ['activation_63[0][0]',
#                                                                      'reshape_21[0][0]']
#
#  add_21 (Add)                (None, 32, 32)               0         ['activation_63[0][0]',
#                                                                      'multiply_21[0][0]']
#
#  max_pooling1d_21 (MaxPooli  (None, 8, 32)                0         ['add_21[0][0]']
#  ng1D)
#
#  flatten_10 (Flatten)        (None, 256)                  0         ['max_pooling1d_21[0][0]']
#
#  dense_64 (Dense)            (None, 128)                  32896     ['flatten_10[0][0]']
#
#  dense_65 (Dense)            (None, 3)                    387       ['dense_64[0][0]']
#
# ==================================================================================================
# Total params: 47675 (186.23 KB)
# Trainable params: 47579 (185.86 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 32

train_epochs = 100
history = model.fit(trainX, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_one_hot), shuffle=True)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 6s 19ms/step - loss: 0.1809 - accuracy: 0.8842 - val_loss: 0.1593 - val_accuracy: 0.8862
# Epoch 2/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1395 - accuracy: 0.9051 - val_loss: 0.1374 - val_accuracy: 0.9156
# Epoch 3/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1456 - accuracy: 0.8994 - val_loss: 0.1244 - val_accuracy: 0.9206
# Epoch 4/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1338 - accuracy: 0.9083 - val_loss: 0.1267 - val_accuracy: 0.9148
# Epoch 5/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1321 - accuracy: 0.9095 - val_loss: 0.1191 - val_accuracy: 0.9238
# Epoch 6/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.1356 - accuracy: 0.9071 - val_loss: 0.1280 - val_accuracy: 0.9140
# Epoch 7/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1272 - accuracy: 0.9162 - val_loss: 0.1169 - val_accuracy: 0.9238
# Epoch 8/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1225 - accuracy: 0.9186 - val_loss: 0.1169 - val_accuracy: 0.9197
# Epoch 9/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1254 - accuracy: 0.9176 - val_loss: 0.1230 - val_accuracy: 0.9206
# Epoch 10/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1126 - accuracy: 0.9245 - val_loss: 0.1081 - val_accuracy: 0.9287
# Epoch 11/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.1136 - accuracy: 0.9257 - val_loss: 0.1029 - val_accuracy: 0.9345
# Epoch 12/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1064 - accuracy: 0.9299 - val_loss: 0.1038 - val_accuracy: 0.9345
# Epoch 13/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1075 - accuracy: 0.9272 - val_loss: 0.0944 - val_accuracy: 0.9386
# Epoch 14/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.1070 - accuracy: 0.9304 - val_loss: 0.0928 - val_accuracy: 0.9427
# Epoch 15/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.1016 - accuracy: 0.9331 - val_loss: 0.0908 - val_accuracy: 0.9419
# Epoch 16/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0950 - accuracy: 0.9378 - val_loss: 0.0930 - val_accuracy: 0.9378
# Epoch 17/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0953 - accuracy: 0.9378 - val_loss: 0.0886 - val_accuracy: 0.9459
# Epoch 18/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1023 - accuracy: 0.9326 - val_loss: 0.0871 - val_accuracy: 0.9468
# Epoch 19/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0980 - accuracy: 0.9368 - val_loss: 0.0917 - val_accuracy: 0.9410
# Epoch 20/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.0916 - accuracy: 0.9405 - val_loss: 0.0828 - val_accuracy: 0.9443
# Epoch 21/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0885 - accuracy: 0.9457 - val_loss: 0.0792 - val_accuracy: 0.9517
# Epoch 22/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0825 - accuracy: 0.9484 - val_loss: 0.0698 - val_accuracy: 0.9574
# Epoch 23/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0916 - accuracy: 0.9437 - val_loss: 0.0927 - val_accuracy: 0.9419
# Epoch 24/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0879 - accuracy: 0.9444 - val_loss: 0.0825 - val_accuracy: 0.9484
# Epoch 25/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0852 - accuracy: 0.9449 - val_loss: 0.0724 - val_accuracy: 0.9550
# Epoch 26/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0857 - accuracy: 0.9447 - val_loss: 0.0736 - val_accuracy: 0.9525
# Epoch 27/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0774 - accuracy: 0.9533 - val_loss: 0.0931 - val_accuracy: 0.9378
# Epoch 28/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0950 - accuracy: 0.9395 - val_loss: 0.0707 - val_accuracy: 0.9550
# Epoch 29/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0897 - accuracy: 0.9427 - val_loss: 0.0700 - val_accuracy: 0.9582
# Epoch 30/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0912 - accuracy: 0.9410 - val_loss: 0.0704 - val_accuracy: 0.9582
# Epoch 31/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0840 - accuracy: 0.9471 - val_loss: 0.0695 - val_accuracy: 0.9541
# Epoch 32/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0746 - accuracy: 0.9552 - val_loss: 0.0830 - val_accuracy: 0.9468
# Epoch 33/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0850 - accuracy: 0.9479 - val_loss: 0.0677 - val_accuracy: 0.9590
# Epoch 34/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.0673 - accuracy: 0.9589 - val_loss: 0.0571 - val_accuracy: 0.9689
# Epoch 35/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0683 - accuracy: 0.9584 - val_loss: 0.0555 - val_accuracy: 0.9697
# Epoch 36/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0679 - accuracy: 0.9597 - val_loss: 0.0604 - val_accuracy: 0.9631
# Epoch 37/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0657 - accuracy: 0.9594 - val_loss: 0.0577 - val_accuracy: 0.9656
# Epoch 38/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0755 - accuracy: 0.9533 - val_loss: 0.0595 - val_accuracy: 0.9640
# Epoch 39/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0629 - accuracy: 0.9624 - val_loss: 0.0506 - val_accuracy: 0.9738
# Epoch 40/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0634 - accuracy: 0.9602 - val_loss: 0.0565 - val_accuracy: 0.9648
# Epoch 41/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0646 - accuracy: 0.9609 - val_loss: 0.0495 - val_accuracy: 0.9730
# Epoch 42/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0664 - accuracy: 0.9589 - val_loss: 0.0537 - val_accuracy: 0.9697
# Epoch 43/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0595 - accuracy: 0.9656 - val_loss: 0.0464 - val_accuracy: 0.9746
# Epoch 44/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0589 - accuracy: 0.9656 - val_loss: 0.0514 - val_accuracy: 0.9713
# Epoch 45/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0553 - accuracy: 0.9678 - val_loss: 0.0526 - val_accuracy: 0.9672
# Epoch 46/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0618 - accuracy: 0.9634 - val_loss: 0.0494 - val_accuracy: 0.9722
# Epoch 47/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0584 - accuracy: 0.9668 - val_loss: 0.0405 - val_accuracy: 0.9803
# Epoch 48/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0559 - accuracy: 0.9673 - val_loss: 0.0400 - val_accuracy: 0.9787
# Epoch 49/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0541 - accuracy: 0.9678 - val_loss: 0.0413 - val_accuracy: 0.9803
# Epoch 50/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0521 - accuracy: 0.9698 - val_loss: 0.0423 - val_accuracy: 0.9795
# Epoch 51/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0520 - accuracy: 0.9700 - val_loss: 0.0369 - val_accuracy: 0.9861
# Epoch 52/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0512 - accuracy: 0.9707 - val_loss: 0.0415 - val_accuracy: 0.9779
# Epoch 53/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0495 - accuracy: 0.9725 - val_loss: 0.0390 - val_accuracy: 0.9820
# Epoch 54/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0542 - accuracy: 0.9678 - val_loss: 0.0498 - val_accuracy: 0.9705
# Epoch 55/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0484 - accuracy: 0.9725 - val_loss: 0.0450 - val_accuracy: 0.9754
# Epoch 56/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0502 - accuracy: 0.9715 - val_loss: 0.0355 - val_accuracy: 0.9844
# Epoch 57/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0443 - accuracy: 0.9752 - val_loss: 0.0377 - val_accuracy: 0.9812
# Epoch 58/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0475 - accuracy: 0.9730 - val_loss: 0.0359 - val_accuracy: 0.9803
# Epoch 59/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0456 - accuracy: 0.9727 - val_loss: 0.0310 - val_accuracy: 0.9869
# Epoch 60/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0496 - accuracy: 0.9722 - val_loss: 0.0456 - val_accuracy: 0.9762
# Epoch 61/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0490 - accuracy: 0.9717 - val_loss: 0.0463 - val_accuracy: 0.9746
# Epoch 62/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0437 - accuracy: 0.9761 - val_loss: 0.0368 - val_accuracy: 0.9803
# Epoch 63/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0452 - accuracy: 0.9727 - val_loss: 0.0356 - val_accuracy: 0.9803
# Epoch 64/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0400 - accuracy: 0.9784 - val_loss: 0.0327 - val_accuracy: 0.9828
# Epoch 65/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0379 - accuracy: 0.9806 - val_loss: 0.0298 - val_accuracy: 0.9869
# Epoch 66/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0371 - accuracy: 0.9798 - val_loss: 0.0330 - val_accuracy: 0.9853
# Epoch 67/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0397 - accuracy: 0.9774 - val_loss: 0.0278 - val_accuracy: 0.9853
# Epoch 68/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0391 - accuracy: 0.9796 - val_loss: 0.0306 - val_accuracy: 0.9853
# Epoch 69/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0366 - accuracy: 0.9798 - val_loss: 0.0403 - val_accuracy: 0.9787
# Epoch 70/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0542 - accuracy: 0.9673 - val_loss: 0.0377 - val_accuracy: 0.9795
# Epoch 71/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0400 - accuracy: 0.9781 - val_loss: 0.0280 - val_accuracy: 0.9894
# Epoch 72/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0468 - accuracy: 0.9722 - val_loss: 0.0311 - val_accuracy: 0.9844
# Epoch 73/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0410 - accuracy: 0.9774 - val_loss: 0.0340 - val_accuracy: 0.9836
# Epoch 74/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0524 - accuracy: 0.9698 - val_loss: 0.0336 - val_accuracy: 0.9812
# Epoch 75/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0398 - accuracy: 0.9786 - val_loss: 0.0294 - val_accuracy: 0.9869
# Epoch 76/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0361 - accuracy: 0.9803 - val_loss: 0.0325 - val_accuracy: 0.9869
# Epoch 77/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0398 - accuracy: 0.9784 - val_loss: 0.0247 - val_accuracy: 0.9902
# Epoch 78/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0308 - accuracy: 0.9852 - val_loss: 0.0254 - val_accuracy: 0.9894
# Epoch 79/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0305 - accuracy: 0.9850 - val_loss: 0.0228 - val_accuracy: 0.9918
# Epoch 80/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0297 - accuracy: 0.9860 - val_loss: 0.0255 - val_accuracy: 0.9894
# Epoch 81/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0341 - accuracy: 0.9818 - val_loss: 0.0323 - val_accuracy: 0.9844
# Epoch 82/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0323 - accuracy: 0.9838 - val_loss: 0.0316 - val_accuracy: 0.9861
# Epoch 83/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0352 - accuracy: 0.9813 - val_loss: 0.0312 - val_accuracy: 0.9844
# Epoch 84/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0290 - accuracy: 0.9870 - val_loss: 0.0380 - val_accuracy: 0.9820
# Epoch 85/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0303 - accuracy: 0.9850 - val_loss: 0.0216 - val_accuracy: 0.9918
# Epoch 86/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0294 - accuracy: 0.9857 - val_loss: 0.0253 - val_accuracy: 0.9885
# Epoch 87/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.0282 - accuracy: 0.9865 - val_loss: 0.0193 - val_accuracy: 0.9934
# Epoch 88/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0275 - accuracy: 0.9887 - val_loss: 0.0228 - val_accuracy: 0.9902
# Epoch 89/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0385 - accuracy: 0.9796 - val_loss: 0.0250 - val_accuracy: 0.9877
# Epoch 90/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0303 - accuracy: 0.9850 - val_loss: 0.0256 - val_accuracy: 0.9894
# Epoch 91/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0282 - accuracy: 0.9870 - val_loss: 0.0301 - val_accuracy: 0.9861
# Epoch 92/100
# 128/128 [==============================] - 2s 14ms/step - loss: 0.0278 - accuracy: 0.9870 - val_loss: 0.0203 - val_accuracy: 0.9926
# Epoch 93/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0278 - accuracy: 0.9872 - val_loss: 0.0204 - val_accuracy: 0.9926
# Epoch 94/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0280 - accuracy: 0.9865 - val_loss: 0.0205 - val_accuracy: 0.9934
# Epoch 95/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0239 - accuracy: 0.9894 - val_loss: 0.0206 - val_accuracy: 0.9910
# Epoch 96/100
# 128/128 [==============================] - 2s 15ms/step - loss: 0.0273 - accuracy: 0.9870 - val_loss: 0.0204 - val_accuracy: 0.9934
# Epoch 97/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0254 - accuracy: 0.9887 - val_loss: 0.0167 - val_accuracy: 0.9959
# Epoch 98/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0242 - accuracy: 0.9904 - val_loss: 0.0196 - val_accuracy: 0.9934
# Epoch 99/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0246 - accuracy: 0.9897 - val_loss: 0.0169 - val_accuracy: 0.9951
# Epoch 100/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0217 - accuracy: 0.9914 - val_loss: 0.0182 - val_accuracy: 0.9943

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(testX)
predy=np.argmax(predy, axis=-1)
LABELS = ['SITTING','STANDIND','LAYING']
cm=confusion_matrix(testy,predy)
print(cm)
print(accuracy_score(testy,predy))
print(f1_score(testy,predy, average='weighted'))
print(classification_report(testy,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 49/49 [==============================] - 0s 4ms/step
# [[435  55   1]
#  [ 12 520   0]
#  [  0   0 537]]
# 0.9564102564102565
# 0.9562223378630649
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       491
#            1       0.90      0.98      0.94       532
#            2       1.00      1.00      1.00       537
#
#     accuracy                           0.96      1560
#    macro avg       0.96      0.95      0.96      1560
# weighted avg       0.96      0.96      0.96      1560
# <Axes: >
